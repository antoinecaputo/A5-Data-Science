# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.5)
# Requirement already satisfied: numpy>=1.20 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.49.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: setuptools in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\valentin\appdata\roaming\python\python310\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: packaging in c:\users\valentin\appdata\roaming\python\python310\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.11.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\valentin\appdata\roaming\python\python310\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\valentin\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# your model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
  annotation_file = '/annotations/captions_train2014.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder

# %%
with open('./annotations/captions_train2014.json', 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths
print(len(train_image_paths))
# Out:
# 82783

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A batter standing in the batter's box during a baseball game. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=314x500>

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in image_dataset:
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)

# We will override the default standardization of TextVectorization to preserve
# "<>" characters, so we preserve the tokens for the <start> and <end>.
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max word count for a caption.
max_length = 50
# Use the top 5000 words for a vocabulary.
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# %%
# Create the tokenized vectors
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (331294, 331294, 82819, 82819)

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 2.0124
# Epoch 1 Batch 100 Loss 1.0982
# Epoch 1 Batch 200 Loss 0.9699
# Epoch 1 Batch 300 Loss 0.8574
# Epoch 1 Batch 400 Loss 0.8070
# Epoch 1 Batch 500 Loss 0.7938
# Epoch 1 Batch 600 Loss 0.8061
# Epoch 1 Batch 700 Loss 0.7556
# Epoch 1 Batch 800 Loss 0.7065
# Epoch 1 Batch 900 Loss 0.7021
# Epoch 1 Batch 1000 Loss 0.7101
# Epoch 1 Batch 1100 Loss 0.7120
# Epoch 1 Batch 1200 Loss 0.7353
# Epoch 1 Batch 1300 Loss 0.6542
# Epoch 1 Batch 1400 Loss 0.6902
# Epoch 1 Batch 1500 Loss 0.7604
# Epoch 1 Batch 1600 Loss 0.6741
# Epoch 1 Batch 1700 Loss 0.6981
# Epoch 1 Batch 1800 Loss 0.7621
# Epoch 1 Batch 1900 Loss 0.6993
# Epoch 1 Batch 2000 Loss 0.7132
# Epoch 1 Batch 2100 Loss 0.7147
# Epoch 1 Batch 2200 Loss 0.6324
# Epoch 1 Batch 2300 Loss 0.6606
# Epoch 1 Batch 2400 Loss 0.6264
# Epoch 1 Batch 2500 Loss 0.6426
# Epoch 1 Batch 2600 Loss 0.6148
# Epoch 1 Batch 2700 Loss 0.6447
# Epoch 1 Batch 2800 Loss 0.7213
# Epoch 1 Batch 2900 Loss 0.6586
# Epoch 1 Batch 3000 Loss 0.5983
# Epoch 1 Batch 3100 Loss 0.6704
# Epoch 1 Batch 3200 Loss 0.6659
# Epoch 1 Batch 3300 Loss 0.7307
# Epoch 1 Batch 3400 Loss 0.6830
# Epoch 1 Batch 3500 Loss 0.6240
# Epoch 1 Batch 3600 Loss 0.6729
# Epoch 1 Batch 3700 Loss 0.6662
# Epoch 1 Batch 3800 Loss 0.6497
# Epoch 1 Batch 3900 Loss 0.6781
# Epoch 1 Batch 4000 Loss 0.6055
# Epoch 1 Batch 4100 Loss 0.6559
# Epoch 1 Batch 4200 Loss 0.6760
# Epoch 1 Batch 4300 Loss 0.6558
# Epoch 1 Batch 4400 Loss 0.6570
# Epoch 1 Batch 4500 Loss 0.7021
# Epoch 1 Batch 4600 Loss 0.6657
# Epoch 1 Batch 4700 Loss 0.6077
# Epoch 1 Batch 4800 Loss 0.6469
# Epoch 1 Batch 4900 Loss 0.6314
# Epoch 1 Batch 5000 Loss 0.6116
# Epoch 1 Batch 5100 Loss 0.6541
# Epoch 1 Loss 0.701555
# Time taken for 1 epoch 1237.65 sec
#
# Epoch 2 Batch 0 Loss 0.6409
# Epoch 2 Batch 100 Loss 0.6469
# Epoch 2 Batch 200 Loss 0.6022
# Epoch 2 Batch 300 Loss 0.6980
# Epoch 2 Batch 400 Loss 0.6190
# Epoch 2 Batch 500 Loss 0.6395
# Epoch 2 Batch 600 Loss 0.5919
# Epoch 2 Batch 700 Loss 0.6312
# Epoch 2 Batch 800 Loss 0.6181
# Epoch 2 Batch 900 Loss 0.6387
# Epoch 2 Batch 1000 Loss 0.6004
# Epoch 2 Batch 1100 Loss 0.6229
# Epoch 2 Batch 1200 Loss 0.5887
# Epoch 2 Batch 1300 Loss 0.6724
# Epoch 2 Batch 1400 Loss 0.6292
# Epoch 2 Batch 1500 Loss 0.6279
# Epoch 2 Batch 1600 Loss 0.6249
# Epoch 2 Batch 1700 Loss 0.6570
# Epoch 2 Batch 1800 Loss 0.7164
# Epoch 2 Batch 1900 Loss 0.6339
# Epoch 2 Batch 2000 Loss 0.6506
# Epoch 2 Batch 2100 Loss 0.6467
# Epoch 2 Batch 2200 Loss 0.6150
# Epoch 2 Batch 2300 Loss 0.6039
# Epoch 2 Batch 2400 Loss 0.5429
# Epoch 2 Batch 2500 Loss 0.6142
# Epoch 2 Batch 2600 Loss 0.6026
# Epoch 2 Batch 2700 Loss 0.6386
# Epoch 2 Batch 2800 Loss 0.5800
# Epoch 2 Batch 2900 Loss 0.5599
# Epoch 2 Batch 3000 Loss 0.5862
# Epoch 2 Batch 3100 Loss 0.5988
# Epoch 2 Batch 3200 Loss 0.6283
# Epoch 2 Batch 3300 Loss 0.6511
# Epoch 2 Batch 3400 Loss 0.5806
# Epoch 2 Batch 3500 Loss 0.5992
# Epoch 2 Batch 3600 Loss 0.5657
# Epoch 2 Batch 3700 Loss 0.6005
# Epoch 2 Batch 3800 Loss 0.6138
# Epoch 2 Batch 3900 Loss 0.6657
# Epoch 2 Batch 4000 Loss 0.6225
# Epoch 2 Batch 4100 Loss 0.6222
# Epoch 2 Batch 4200 Loss 0.6154
# Epoch 2 Batch 4300 Loss 0.5721
# Epoch 2 Batch 4400 Loss 0.5843
# Epoch 2 Batch 4500 Loss 0.5633
# Epoch 2 Batch 4600 Loss 0.5730
# Epoch 2 Batch 4700 Loss 0.6145
# Epoch 2 Batch 4800 Loss 0.6370
# Epoch 2 Batch 4900 Loss 0.5779
# Epoch 2 Batch 5000 Loss 0.5695
# Epoch 2 Batch 5100 Loss 0.6286
# Epoch 2 Loss 0.614479
# Time taken for 1 epoch 1148.20 sec
#
# Epoch 3 Batch 0 Loss 0.6383
# Epoch 3 Batch 100 Loss 0.5908
# Epoch 3 Batch 200 Loss 0.5939
# Epoch 3 Batch 300 Loss 0.5644
# Epoch 3 Batch 400 Loss 0.6451
# Epoch 3 Batch 500 Loss 0.6418
# Epoch 3 Batch 600 Loss 0.5667
# Epoch 3 Batch 700 Loss 0.5936
# Epoch 3 Batch 800 Loss 0.5613
# Epoch 3 Batch 900 Loss 0.5620
# Epoch 3 Batch 1000 Loss 0.6303
# Epoch 3 Batch 1100 Loss 0.5656
# Epoch 3 Batch 1200 Loss 0.5659
# Epoch 3 Batch 1300 Loss 0.6736
# Epoch 3 Batch 1400 Loss 0.5888
# Epoch 3 Batch 1500 Loss 0.5867
# Epoch 3 Batch 1600 Loss 0.5529
# Epoch 3 Batch 1700 Loss 0.5895
# Epoch 3 Batch 1800 Loss 0.6040
# Epoch 3 Batch 1900 Loss 0.5786
# Epoch 3 Batch 2000 Loss 0.6042
# Epoch 3 Batch 2100 Loss 0.6126
# Epoch 3 Batch 2200 Loss 0.6412
# Epoch 3 Batch 2300 Loss 0.5763
# Epoch 3 Batch 2400 Loss 0.6407
# Epoch 3 Batch 2500 Loss 0.5674
# Epoch 3 Batch 2600 Loss 0.5730
# Epoch 3 Batch 2700 Loss 0.5875
# Epoch 3 Batch 2800 Loss 0.6029
# Epoch 3 Batch 2900 Loss 0.6293
# Epoch 3 Batch 3000 Loss 0.6393
# Epoch 3 Batch 3100 Loss 0.5712
# Epoch 3 Batch 3200 Loss 0.5758
# Epoch 3 Batch 3300 Loss 0.6328
# Epoch 3 Batch 3400 Loss 0.6036
# Epoch 3 Batch 3500 Loss 0.5883
# Epoch 3 Batch 3600 Loss 0.5087
# Epoch 3 Batch 3700 Loss 0.5237
# Epoch 3 Batch 3800 Loss 0.5727
# Epoch 3 Batch 3900 Loss 0.6013
# Epoch 3 Batch 4000 Loss 0.5634
# Epoch 3 Batch 4100 Loss 0.6085
# Epoch 3 Batch 4200 Loss 0.5865
# Epoch 3 Batch 4300 Loss 0.5215
# Epoch 3 Batch 4400 Loss 0.6128
# Epoch 3 Batch 4500 Loss 0.6101
# Epoch 3 Batch 4600 Loss 0.5808
# Epoch 3 Batch 4700 Loss 0.5594
# Epoch 3 Batch 4800 Loss 0.5769
# Epoch 3 Batch 4900 Loss 0.5961
# Epoch 3 Batch 5000 Loss 0.6206
# Epoch 3 Batch 5100 Loss 0.5994
# Epoch 3 Loss 0.588676
# Time taken for 1 epoch 1124.96 sec
#
# Epoch 4 Batch 0 Loss 0.6183
# Epoch 4 Batch 100 Loss 0.5624
# Epoch 4 Batch 200 Loss 0.5545
# Epoch 4 Batch 300 Loss 0.6072
# Epoch 4 Batch 400 Loss 0.5873
# Epoch 4 Batch 500 Loss 0.5703
# Epoch 4 Batch 600 Loss 0.5828
# Epoch 4 Batch 700 Loss 0.5584
# Epoch 4 Batch 800 Loss 0.5551
# Epoch 4 Batch 900 Loss 0.5778
# Epoch 4 Batch 1000 Loss 0.5964
# Epoch 4 Batch 1100 Loss 0.4987
# Epoch 4 Batch 1200 Loss 0.5816
# Epoch 4 Batch 1300 Loss 0.6178
# Epoch 4 Batch 1400 Loss 0.6002
# Epoch 4 Batch 1500 Loss 0.5525
# Epoch 4 Batch 1600 Loss 0.6162
# Epoch 4 Batch 1700 Loss 0.5258
# Epoch 4 Batch 1800 Loss 0.5638
# Epoch 4 Batch 1900 Loss 0.6250
# Epoch 4 Batch 2000 Loss 0.5845
# Epoch 4 Batch 2100 Loss 0.5703
# Epoch 4 Batch 2200 Loss 0.5505
# Epoch 4 Batch 2300 Loss 0.5723
# Epoch 4 Batch 2400 Loss 0.5891
# Epoch 4 Batch 2500 Loss 0.5715
# Epoch 4 Batch 2600 Loss 0.5363
# Epoch 4 Batch 2700 Loss 0.5639
# Epoch 4 Batch 2800 Loss 0.5165
# Epoch 4 Batch 2900 Loss 0.5730
# Epoch 4 Batch 3000 Loss 0.5304
# Epoch 4 Batch 3100 Loss 0.5345
# Epoch 4 Batch 3200 Loss 0.5320
# Epoch 4 Batch 3300 Loss 0.5015
# Epoch 4 Batch 3400 Loss 0.5840
# Epoch 4 Batch 3500 Loss 0.5752
# Epoch 4 Batch 3600 Loss 0.5211
# Epoch 4 Batch 3700 Loss 0.5912
# Epoch 4 Batch 3800 Loss 0.5846
# Epoch 4 Batch 3900 Loss 0.6439
# Epoch 4 Batch 4000 Loss 0.5874
# Epoch 4 Batch 4100 Loss 0.5600
# Epoch 4 Batch 4200 Loss 0.5742
# Epoch 4 Batch 4300 Loss 0.5410
# Epoch 4 Batch 4400 Loss 0.5279
# Epoch 4 Batch 4500 Loss 0.5718
# Epoch 4 Batch 4600 Loss 0.6220
# Epoch 4 Batch 4700 Loss 0.5453
# Epoch 4 Batch 4800 Loss 0.5798
# Epoch 4 Batch 4900 Loss 0.5716
# Epoch 4 Batch 5000 Loss 0.5506
# Epoch 4 Batch 5100 Loss 0.5627
# Epoch 4 Loss 0.571548
# Time taken for 1 epoch 1135.57 sec
#
# Epoch 5 Batch 0 Loss 0.5736
# Epoch 5 Batch 100 Loss 0.5911
# Epoch 5 Batch 200 Loss 0.5092
# Epoch 5 Batch 300 Loss 0.5738
# Epoch 5 Batch 400 Loss 0.5817
# Epoch 5 Batch 500 Loss 0.5586
# Epoch 5 Batch 600 Loss 0.5027
# Epoch 5 Batch 700 Loss 0.6058
# Epoch 5 Batch 800 Loss 0.5920
# Epoch 5 Batch 900 Loss 0.5444
# Epoch 5 Batch 1000 Loss 0.5459
# Epoch 5 Batch 1100 Loss 0.5779
# Epoch 5 Batch 1200 Loss 0.6518
# Epoch 5 Batch 1300 Loss 0.5167
# Epoch 5 Batch 1400 Loss 0.5716
# Epoch 5 Batch 1500 Loss 0.5699
# Epoch 5 Batch 1600 Loss 0.5361
# Epoch 5 Batch 1700 Loss 0.5979
# Epoch 5 Batch 1800 Loss 0.5358
# Epoch 5 Batch 1900 Loss 0.5920
# Epoch 5 Batch 2000 Loss 0.5624
# Epoch 5 Batch 2100 Loss 0.5911
# Epoch 5 Batch 2200 Loss 0.5670
# Epoch 5 Batch 2300 Loss 0.5176
# Epoch 5 Batch 2400 Loss 0.5400
# Epoch 5 Batch 2500 Loss 0.5568
# Epoch 5 Batch 2600 Loss 0.5580
# Epoch 5 Batch 2700 Loss 0.5456
# Epoch 5 Batch 2800 Loss 0.5569
# Epoch 5 Batch 2900 Loss 0.6467
# Epoch 5 Batch 3000 Loss 0.5417
# Epoch 5 Batch 3100 Loss 0.5663
# Epoch 5 Batch 3200 Loss 0.5769
# Epoch 5 Batch 3300 Loss 0.5224
# Epoch 5 Batch 3400 Loss 0.5763
# Epoch 5 Batch 3500 Loss 0.6148
# Epoch 5 Batch 3600 Loss 0.5410
# Epoch 5 Batch 3700 Loss 0.5887
# Epoch 5 Batch 3800 Loss 0.5484
# Epoch 5 Batch 3900 Loss 0.5442
# Epoch 5 Batch 4000 Loss 0.5767
# Epoch 5 Batch 4100 Loss 0.5433
# Epoch 5 Batch 4200 Loss 0.5758
# Epoch 5 Batch 4300 Loss 0.5461
# Epoch 5 Batch 4400 Loss 0.5752
# Epoch 5 Batch 4500 Loss 0.5580
# Epoch 5 Batch 4600 Loss 0.6155
# Epoch 5 Batch 4700 Loss 0.5369
# Epoch 5 Batch 4800 Loss 0.5241
# Epoch 5 Batch 4900 Loss 0.5490
# Epoch 5 Batch 5000 Loss 0.5703
# Epoch 5 Batch 5100 Loss 0.5754
# Epoch 5 Loss 0.557987
# Time taken for 1 epoch 1123.39 sec
#
# Epoch 6 Batch 0 Loss 0.5524
# Epoch 6 Batch 100 Loss 0.5923
# Epoch 6 Batch 200 Loss 0.5471
# Epoch 6 Batch 300 Loss 0.5558
# Epoch 6 Batch 400 Loss 0.5001
# Epoch 6 Batch 500 Loss 0.5265
# Epoch 6 Batch 600 Loss 0.5264
# Epoch 6 Batch 700 Loss 0.4788
# Epoch 6 Batch 800 Loss 0.5263
# Epoch 6 Batch 900 Loss 0.5123
# Epoch 6 Batch 1000 Loss 0.5350
# Epoch 6 Batch 1100 Loss 0.5324
# Epoch 6 Batch 1200 Loss 0.5437
# Epoch 6 Batch 1300 Loss 0.5709
# Epoch 6 Batch 1400 Loss 0.5806
# Epoch 6 Batch 1500 Loss 0.5521
# Epoch 6 Batch 1600 Loss 0.5530
# Epoch 6 Batch 1700 Loss 0.5964
# Epoch 6 Batch 1800 Loss 0.5409
# Epoch 6 Batch 1900 Loss 0.5676
# Epoch 6 Batch 2000 Loss 0.5379
# Epoch 6 Batch 2100 Loss 0.5701
# Epoch 6 Batch 2200 Loss 0.5511
# Epoch 6 Batch 2300 Loss 0.5961
# Epoch 6 Batch 2400 Loss 0.5334
# Epoch 6 Batch 2500 Loss 0.5332
# Epoch 6 Batch 2600 Loss 0.5327
# Epoch 6 Batch 2700 Loss 0.5472
# Epoch 6 Batch 2800 Loss 0.5792
# Epoch 6 Batch 2900 Loss 0.5270
# Epoch 6 Batch 3000 Loss 0.5180
# Epoch 6 Batch 3100 Loss 0.5168
# Epoch 6 Batch 3200 Loss 0.5692
# Epoch 6 Batch 3300 Loss 0.5259
# Epoch 6 Batch 3400 Loss 0.5648
# Epoch 6 Batch 3500 Loss 0.5847
# Epoch 6 Batch 3600 Loss 0.5027
# Epoch 6 Batch 3700 Loss 0.5206
# Epoch 6 Batch 3800 Loss 0.5490
# Epoch 6 Batch 3900 Loss 0.5594
# Epoch 6 Batch 4000 Loss 0.5472
# Epoch 6 Batch 4100 Loss 0.5007
# Epoch 6 Batch 4200 Loss 0.5591
# Epoch 6 Batch 4300 Loss 0.5565
# Epoch 6 Batch 4400 Loss 0.5468
# Epoch 6 Batch 4500 Loss 0.5071
# Epoch 6 Batch 4600 Loss 0.5310
# Epoch 6 Batch 4700 Loss 0.5504
# Epoch 6 Batch 4800 Loss 0.5205
# Epoch 6 Batch 4900 Loss 0.4991
# Epoch 6 Batch 5000 Loss 0.5108
# Epoch 6 Batch 5100 Loss 0.5322
# Epoch 6 Loss 0.546788
# Time taken for 1 epoch 1107.00 sec
#
# Epoch 7 Batch 0 Loss 0.5675
# Epoch 7 Batch 100 Loss 0.5289
# Epoch 7 Batch 200 Loss 0.5618
# Epoch 7 Batch 300 Loss 0.5667
# Epoch 7 Batch 400 Loss 0.5139
# Epoch 7 Batch 500 Loss 0.5191
# Epoch 7 Batch 600 Loss 0.5860
# Epoch 7 Batch 700 Loss 0.5182
# Epoch 7 Batch 800 Loss 0.5062
# Epoch 7 Batch 900 Loss 0.5239
# Epoch 7 Batch 1000 Loss 0.5471
# Epoch 7 Batch 1100 Loss 0.5715
# Epoch 7 Batch 1200 Loss 0.5222
# Epoch 7 Batch 1300 Loss 0.5342
# Epoch 7 Batch 1400 Loss 0.5434
# Epoch 7 Batch 1500 Loss 0.5423
# Epoch 7 Batch 1600 Loss 0.5435
# Epoch 7 Batch 1700 Loss 0.5597
# Epoch 7 Batch 1800 Loss 0.5264
# Epoch 7 Batch 1900 Loss 0.5420
# Epoch 7 Batch 2000 Loss 0.5859
# Epoch 7 Batch 2100 Loss 0.5471
# Epoch 7 Batch 2200 Loss 0.5616
# Epoch 7 Batch 2300 Loss 0.5325
# Epoch 7 Batch 2400 Loss 0.4970
# Epoch 7 Batch 2500 Loss 0.5358
# Epoch 7 Batch 2600 Loss 0.5338
# Epoch 7 Batch 2700 Loss 0.5756
# Epoch 7 Batch 2800 Loss 0.5348
# Epoch 7 Batch 2900 Loss 0.5568
# Epoch 7 Batch 3000 Loss 0.5377
# Epoch 7 Batch 3100 Loss 0.5083
# Epoch 7 Batch 3200 Loss 0.5477
# Epoch 7 Batch 3300 Loss 0.5556
# Epoch 7 Batch 3400 Loss 0.5153
# Epoch 7 Batch 3500 Loss 0.5035
# Epoch 7 Batch 3600 Loss 0.5363
# Epoch 7 Batch 3700 Loss 0.5279
# Epoch 7 Batch 3800 Loss 0.5430
# Epoch 7 Batch 3900 Loss 0.5177
# Epoch 7 Batch 4000 Loss 0.5371
# Epoch 7 Batch 4100 Loss 0.5229
# Epoch 7 Batch 4200 Loss 0.5148
# Epoch 7 Batch 4300 Loss 0.5609
# Epoch 7 Batch 4400 Loss 0.5174
# Epoch 7 Batch 4500 Loss 0.5370
# Epoch 7 Batch 4600 Loss 0.5787
# Epoch 7 Batch 4700 Loss 0.5546
# Epoch 7 Batch 4800 Loss 0.4911
# Epoch 7 Batch 4900 Loss 0.5906
# Epoch 7 Batch 5000 Loss 0.5106
# Epoch 7 Batch 5100 Loss 0.5710
# Epoch 7 Loss 0.536737
# Time taken for 1 epoch 1069.36 sec
#
# Epoch 8 Batch 0 Loss 0.5518
# Epoch 8 Batch 100 Loss 0.5495
# Epoch 8 Batch 200 Loss 0.5106
# Epoch 8 Batch 300 Loss 0.5065
# Epoch 8 Batch 400 Loss 0.5107
# Epoch 8 Batch 500 Loss 0.5111
# Epoch 8 Batch 600 Loss 0.5539
# Epoch 8 Batch 700 Loss 0.5094
# Epoch 8 Batch 800 Loss 0.4909
# Epoch 8 Batch 900 Loss 0.5467
# Epoch 8 Batch 1000 Loss 0.5529
# Epoch 8 Batch 1100 Loss 0.4779
# Epoch 8 Batch 1200 Loss 0.5774
# Epoch 8 Batch 1300 Loss 0.5739
# Epoch 8 Batch 1400 Loss 0.5048
# Epoch 8 Batch 1500 Loss 0.5148
# Epoch 8 Batch 1600 Loss 0.5337
# Epoch 8 Batch 1700 Loss 0.5260
# Epoch 8 Batch 1800 Loss 0.4883
# Epoch 8 Batch 1900 Loss 0.5328
# Epoch 8 Batch 2000 Loss 0.5336
# Epoch 8 Batch 2100 Loss 0.5025
# Epoch 8 Batch 2200 Loss 0.5596
# Epoch 8 Batch 2300 Loss 0.4895
# Epoch 8 Batch 2400 Loss 0.5022
# Epoch 8 Batch 2500 Loss 0.5083
# Epoch 8 Batch 2600 Loss 0.5325
# Epoch 8 Batch 2700 Loss 0.4852
# Epoch 8 Batch 2800 Loss 0.5603
# Epoch 8 Batch 2900 Loss 0.5450
# Epoch 8 Batch 3000 Loss 0.4833
# Epoch 8 Batch 3100 Loss 0.5484
# Epoch 8 Batch 3200 Loss 0.5148
# Epoch 8 Batch 3300 Loss 0.5125
# Epoch 8 Batch 3400 Loss 0.5471
# Epoch 8 Batch 3500 Loss 0.5789
# Epoch 8 Batch 3600 Loss 0.5329
# Epoch 8 Batch 3700 Loss 0.4471
# Epoch 8 Batch 3800 Loss 0.5752
# Epoch 8 Batch 3900 Loss 0.5895
# Epoch 8 Batch 4000 Loss 0.4855
# Epoch 8 Batch 4100 Loss 0.5485
# Epoch 8 Batch 4200 Loss 0.5442
# Epoch 8 Batch 4300 Loss 0.5233
# Epoch 8 Batch 4400 Loss 0.5609
# Epoch 8 Batch 4500 Loss 0.4893
# Epoch 8 Batch 4600 Loss 0.5427
# Epoch 8 Batch 4700 Loss 0.5295
# Epoch 8 Batch 4800 Loss 0.5349
# Epoch 8 Batch 4900 Loss 0.5135
# Epoch 8 Batch 5000 Loss 0.4853
# Epoch 8 Batch 5100 Loss 0.5280
# Epoch 8 Loss 0.527789
# Time taken for 1 epoch 1043.09 sec
#
# Epoch 9 Batch 0 Loss 0.5612
# Epoch 9 Batch 100 Loss 0.4981
# Epoch 9 Batch 200 Loss 0.5298
# Epoch 9 Batch 300 Loss 0.5007
# Epoch 9 Batch 400 Loss 0.4644
# Epoch 9 Batch 500 Loss 0.5257
# Epoch 9 Batch 600 Loss 0.4712
# Epoch 9 Batch 700 Loss 0.5233
# Epoch 9 Batch 800 Loss 0.5099
# Epoch 9 Batch 900 Loss 0.5065
# Epoch 9 Batch 1000 Loss 0.5288
# Epoch 9 Batch 1100 Loss 0.4833
# Epoch 9 Batch 1200 Loss 0.5206
# Epoch 9 Batch 1300 Loss 0.5039
# Epoch 9 Batch 1400 Loss 0.5416
# Epoch 9 Batch 1500 Loss 0.5160
# Epoch 9 Batch 1600 Loss 0.5073
# Epoch 9 Batch 1700 Loss 0.5312
# Epoch 9 Batch 1800 Loss 0.5162
# Epoch 9 Batch 1900 Loss 0.5052
# Epoch 9 Batch 2000 Loss 0.5170
# Epoch 9 Batch 2100 Loss 0.5031
# Epoch 9 Batch 2200 Loss 0.5183
# Epoch 9 Batch 2300 Loss 0.4680
# Epoch 9 Batch 2400 Loss 0.5172
# Epoch 9 Batch 2500 Loss 0.5091
# Epoch 9 Batch 2600 Loss 0.5777
# Epoch 9 Batch 2700 Loss 0.5162
# Epoch 9 Batch 2800 Loss 0.4958
# Epoch 9 Batch 2900 Loss 0.5131
# Epoch 9 Batch 3000 Loss 0.4994
# Epoch 9 Batch 3100 Loss 0.4360
# Epoch 9 Batch 3200 Loss 0.5236
# Epoch 9 Batch 3300 Loss 0.5024
# Epoch 9 Batch 3400 Loss 0.5335
# Epoch 9 Batch 3500 Loss 0.5498
# Epoch 9 Batch 3600 Loss 0.5326
# Epoch 9 Batch 3700 Loss 0.5151
# Epoch 9 Batch 3800 Loss 0.5010
# Epoch 9 Batch 3900 Loss 0.5330
# Epoch 9 Batch 4000 Loss 0.4762
# Epoch 9 Batch 4100 Loss 0.5024
# Epoch 9 Batch 4200 Loss 0.5304
# Epoch 9 Batch 4300 Loss 0.5611
# Epoch 9 Batch 4400 Loss 0.5300
# Epoch 9 Batch 4500 Loss 0.5069
# Epoch 9 Batch 4600 Loss 0.5167
# Epoch 9 Batch 4700 Loss 0.4807
# Epoch 9 Batch 4800 Loss 0.5330
# Epoch 9 Batch 4900 Loss 0.5617
# Epoch 9 Batch 5000 Loss 0.4984
# Epoch 9 Batch 5100 Loss 0.4782
# Epoch 9 Loss 0.519757
# Time taken for 1 epoch 1043.48 sec
#
# Epoch 10 Batch 0 Loss 0.5101
# Epoch 10 Batch 100 Loss 0.5086
# Epoch 10 Batch 200 Loss 0.5159
# Epoch 10 Batch 300 Loss 0.5584
# Epoch 10 Batch 400 Loss 0.5128
# Epoch 10 Batch 500 Loss 0.5102
# Epoch 10 Batch 600 Loss 0.5064
# Epoch 10 Batch 700 Loss 0.5209
# Epoch 10 Batch 800 Loss 0.5113
# Epoch 10 Batch 900 Loss 0.5120
# Epoch 10 Batch 1000 Loss 0.5529
# Epoch 10 Batch 1100 Loss 0.5384
# Epoch 10 Batch 1200 Loss 0.5237
# Epoch 10 Batch 1300 Loss 0.4575
# Epoch 10 Batch 1400 Loss 0.4657
# Epoch 10 Batch 1500 Loss 0.5417
# Epoch 10 Batch 1600 Loss 0.4402
# Epoch 10 Batch 1700 Loss 0.4943
# Epoch 10 Batch 1800 Loss 0.4694
# Epoch 10 Batch 1900 Loss 0.4752
# Epoch 10 Batch 2000 Loss 0.5182
# Epoch 10 Batch 2100 Loss 0.5304
# Epoch 10 Batch 2200 Loss 0.5119
# Epoch 10 Batch 2300 Loss 0.5360
# Epoch 10 Batch 2400 Loss 0.4710
# Epoch 10 Batch 2500 Loss 0.4987
# Epoch 10 Batch 2600 Loss 0.5209
# Epoch 10 Batch 2700 Loss 0.4999
# Epoch 10 Batch 2800 Loss 0.5149
# Epoch 10 Batch 2900 Loss 0.4858
# Epoch 10 Batch 3000 Loss 0.5218
# Epoch 10 Batch 3100 Loss 0.4890
# Epoch 10 Batch 3200 Loss 0.5090
# Epoch 10 Batch 3300 Loss 0.4587
# Epoch 10 Batch 3400 Loss 0.5432
# Epoch 10 Batch 3500 Loss 0.5188
# Epoch 10 Batch 3600 Loss 0.5671
# Epoch 10 Batch 3700 Loss 0.5121
# Epoch 10 Batch 3800 Loss 0.5255
# Epoch 10 Batch 3900 Loss 0.4857
# Epoch 10 Batch 4000 Loss 0.5108
# Epoch 10 Batch 4100 Loss 0.4961
# Epoch 10 Batch 4200 Loss 0.4880
# Epoch 10 Batch 4300 Loss 0.5073
# Epoch 10 Batch 4400 Loss 0.5203
# Epoch 10 Batch 4500 Loss 0.5198
# Epoch 10 Batch 4600 Loss 0.5159
# Epoch 10 Batch 4700 Loss 0.5042
# Epoch 10 Batch 4800 Loss 0.5669
# Epoch 10 Batch 4900 Loss 0.4931
# Epoch 10 Batch 5000 Loss 0.5521
# Epoch 10 Batch 5100 Loss 0.5099
# Epoch 10 Loss 0.512341
# Time taken for 1 epoch 1044.09 sec
#
# Epoch 11 Batch 0 Loss 0.5250
# Epoch 11 Batch 100 Loss 0.5180
# Epoch 11 Batch 200 Loss 0.5092
# Epoch 11 Batch 300 Loss 0.5177
# Epoch 11 Batch 400 Loss 0.4620
# Epoch 11 Batch 500 Loss 0.4862
# Epoch 11 Batch 600 Loss 0.4876
# Epoch 11 Batch 700 Loss 0.4701
# Epoch 11 Batch 800 Loss 0.5255
# Epoch 11 Batch 900 Loss 0.4776
# Epoch 11 Batch 1000 Loss 0.5065
# Epoch 11 Batch 1100 Loss 0.4714
# Epoch 11 Batch 1200 Loss 0.5432
# Epoch 11 Batch 1300 Loss 0.5180
# Epoch 11 Batch 1400 Loss 0.5481
# Epoch 11 Batch 1500 Loss 0.5094
# Epoch 11 Batch 1600 Loss 0.4903
# Epoch 11 Batch 1700 Loss 0.5049
# Epoch 11 Batch 1800 Loss 0.5203
# Epoch 11 Batch 1900 Loss 0.4911
# Epoch 11 Batch 2000 Loss 0.4783
# Epoch 11 Batch 2100 Loss 0.4971
# Epoch 11 Batch 2200 Loss 0.5243
# Epoch 11 Batch 2300 Loss 0.5177
# Epoch 11 Batch 2400 Loss 0.4539
# Epoch 11 Batch 2500 Loss 0.4498
# Epoch 11 Batch 2600 Loss 0.5204
# Epoch 11 Batch 2700 Loss 0.5033
# Epoch 11 Batch 2800 Loss 0.4856
# Epoch 11 Batch 2900 Loss 0.5258
# Epoch 11 Batch 3000 Loss 0.4606
# Epoch 11 Batch 3100 Loss 0.4606
# Epoch 11 Batch 3200 Loss 0.5160
# Epoch 11 Batch 3300 Loss 0.4878
# Epoch 11 Batch 3400 Loss 0.5283
# Epoch 11 Batch 3500 Loss 0.5068
# Epoch 11 Batch 3600 Loss 0.5488
# Epoch 11 Batch 3700 Loss 0.4723
# Epoch 11 Batch 3800 Loss 0.4953
# Epoch 11 Batch 3900 Loss 0.4984
# Epoch 11 Batch 4000 Loss 0.5268
# Epoch 11 Batch 4100 Loss 0.4974
# Epoch 11 Batch 4200 Loss 0.5448
# Epoch 11 Batch 4300 Loss 0.5195
# Epoch 11 Batch 4400 Loss 0.4651
# Epoch 11 Batch 4500 Loss 0.5148
# Epoch 11 Batch 4600 Loss 0.5184
# Epoch 11 Batch 4700 Loss 0.5120
# Epoch 11 Batch 4800 Loss 0.5119
# Epoch 11 Batch 4900 Loss 0.4991
# Epoch 11 Batch 5000 Loss 0.5709
# Epoch 11 Batch 5100 Loss 0.4917
# Epoch 11 Loss 0.505702
# Time taken for 1 epoch 1046.09 sec
#
# Epoch 12 Batch 0 Loss 0.5008
# Epoch 12 Batch 100 Loss 0.4802
# Epoch 12 Batch 200 Loss 0.5155
# Epoch 12 Batch 300 Loss 0.5337
# Epoch 12 Batch 400 Loss 0.4192
# Epoch 12 Batch 500 Loss 0.4920
# Epoch 12 Batch 600 Loss 0.4974
# Epoch 12 Batch 700 Loss 0.5078
# Epoch 12 Batch 800 Loss 0.4882
# Epoch 12 Batch 900 Loss 0.5386
# Epoch 12 Batch 1000 Loss 0.4924
# Epoch 12 Batch 1100 Loss 0.4627
# Epoch 12 Batch 1200 Loss 0.5165
# Epoch 12 Batch 1300 Loss 0.4905
# Epoch 12 Batch 1400 Loss 0.5076
# Epoch 12 Batch 1500 Loss 0.5210
# Epoch 12 Batch 1600 Loss 0.4911
# Epoch 12 Batch 1700 Loss 0.4720
# Epoch 12 Batch 1800 Loss 0.5191
# Epoch 12 Batch 1900 Loss 0.4843
# Epoch 12 Batch 2000 Loss 0.5135
# Epoch 12 Batch 2100 Loss 0.5306
# Epoch 12 Batch 2200 Loss 0.5345
# Epoch 12 Batch 2300 Loss 0.5111
# Epoch 12 Batch 2400 Loss 0.5088
# Epoch 12 Batch 2500 Loss 0.4925
# Epoch 12 Batch 2600 Loss 0.4930
# Epoch 12 Batch 2700 Loss 0.4790
# Epoch 12 Batch 2800 Loss 0.5576
# Epoch 12 Batch 2900 Loss 0.5307
# Epoch 12 Batch 3000 Loss 0.5339
# Epoch 12 Batch 3100 Loss 0.5412
# Epoch 12 Batch 3200 Loss 0.4343
# Epoch 12 Batch 3300 Loss 0.5299
# Epoch 12 Batch 3400 Loss 0.4650
# Epoch 12 Batch 3500 Loss 0.5006
# Epoch 12 Batch 3600 Loss 0.4702
# Epoch 12 Batch 3700 Loss 0.4966
# Epoch 12 Batch 3800 Loss 0.4804
# Epoch 12 Batch 3900 Loss 0.5278
# Epoch 12 Batch 4000 Loss 0.4863
# Epoch 12 Batch 4100 Loss 0.4893
# Epoch 12 Batch 4200 Loss 0.4649
# Epoch 12 Batch 4300 Loss 0.4957
# Epoch 12 Batch 4400 Loss 0.5396
# Epoch 12 Batch 4500 Loss 0.4971
# Epoch 12 Batch 4600 Loss 0.4753
# Epoch 12 Batch 4700 Loss 0.4869
# Epoch 12 Batch 4800 Loss 0.4890
# Epoch 12 Batch 4900 Loss 0.4571
# Epoch 12 Batch 5000 Loss 0.5595
# Epoch 12 Batch 5100 Loss 0.4876
# Epoch 12 Loss 0.499798
# Time taken for 1 epoch 1048.79 sec
#
# Epoch 13 Batch 0 Loss 0.5014
# Epoch 13 Batch 100 Loss 0.4846
# Epoch 13 Batch 200 Loss 0.4800
# Epoch 13 Batch 300 Loss 0.4670
# Epoch 13 Batch 400 Loss 0.5112
# Epoch 13 Batch 500 Loss 0.4667
# Epoch 13 Batch 600 Loss 0.5226
# Epoch 13 Batch 700 Loss 0.4725
# Epoch 13 Batch 800 Loss 0.5210
# Epoch 13 Batch 900 Loss 0.4910
# Epoch 13 Batch 1000 Loss 0.4928
# Epoch 13 Batch 1100 Loss 0.4818
# Epoch 13 Batch 1200 Loss 0.4979
# Epoch 13 Batch 1300 Loss 0.4830
# Epoch 13 Batch 1400 Loss 0.5108
# Epoch 13 Batch 1500 Loss 0.4873
# Epoch 13 Batch 1600 Loss 0.5252
# Epoch 13 Batch 1700 Loss 0.4671
# Epoch 13 Batch 1800 Loss 0.5105
# Epoch 13 Batch 1900 Loss 0.4492
# Epoch 13 Batch 2000 Loss 0.4985
# Epoch 13 Batch 2100 Loss 0.4928
# Epoch 13 Batch 2200 Loss 0.5256
# Epoch 13 Batch 2300 Loss 0.4720
# Epoch 13 Batch 2400 Loss 0.4951
# Epoch 13 Batch 2500 Loss 0.5046
# Epoch 13 Batch 2600 Loss 0.4531
# Epoch 13 Batch 2700 Loss 0.5599
# Epoch 13 Batch 2800 Loss 0.4769
# Epoch 13 Batch 2900 Loss 0.4433
# Epoch 13 Batch 3000 Loss 0.5032
# Epoch 13 Batch 3100 Loss 0.5411
# Epoch 13 Batch 3200 Loss 0.4751
# Epoch 13 Batch 3300 Loss 0.5030
# Epoch 13 Batch 3400 Loss 0.4950
# Epoch 13 Batch 3500 Loss 0.5593
# Epoch 13 Batch 3600 Loss 0.5374
# Epoch 13 Batch 3700 Loss 0.5134
# Epoch 13 Batch 3800 Loss 0.4938
# Epoch 13 Batch 3900 Loss 0.5138
# Epoch 13 Batch 4000 Loss 0.4924
# Epoch 13 Batch 4100 Loss 0.4785
# Epoch 13 Batch 4200 Loss 0.4978
# Epoch 13 Batch 4300 Loss 0.5047
# Epoch 13 Batch 4400 Loss 0.4886
# Epoch 13 Batch 4500 Loss 0.4997
# Epoch 13 Batch 4600 Loss 0.4647
# Epoch 13 Batch 4700 Loss 0.4908
# Epoch 13 Batch 4800 Loss 0.5185
# Epoch 13 Batch 4900 Loss 0.4736
# Epoch 13 Batch 5000 Loss 0.4759
# Epoch 13 Batch 5100 Loss 0.5048
# Epoch 13 Loss 0.494315
# Time taken for 1 epoch 1049.59 sec
#
# Epoch 14 Batch 0 Loss 0.5100
# Epoch 14 Batch 100 Loss 0.4716
# Epoch 14 Batch 200 Loss 0.4657
# Epoch 14 Batch 300 Loss 0.5199
# Epoch 14 Batch 400 Loss 0.4560
# Epoch 14 Batch 500 Loss 0.4539
# Epoch 14 Batch 600 Loss 0.4688
# Epoch 14 Batch 700 Loss 0.4682
# Epoch 14 Batch 800 Loss 0.4787
# Epoch 14 Batch 900 Loss 0.4970
# Epoch 14 Batch 1000 Loss 0.4771
# Epoch 14 Batch 1100 Loss 0.4990
# Epoch 14 Batch 1200 Loss 0.4670
# Epoch 14 Batch 1300 Loss 0.5014
# Epoch 14 Batch 1400 Loss 0.5024
# Epoch 14 Batch 1500 Loss 0.5130
# Epoch 14 Batch 1600 Loss 0.5042
# Epoch 14 Batch 1700 Loss 0.4391
# Epoch 14 Batch 1800 Loss 0.4854
# Epoch 14 Batch 1900 Loss 0.4864
# Epoch 14 Batch 2000 Loss 0.4692
# Epoch 14 Batch 2100 Loss 0.5045
# Epoch 14 Batch 2200 Loss 0.5337
# Epoch 14 Batch 2300 Loss 0.4456
# Epoch 14 Batch 2400 Loss 0.4742
# Epoch 14 Batch 2500 Loss 0.4646
# Epoch 14 Batch 2600 Loss 0.4601
# Epoch 14 Batch 2700 Loss 0.4617
# Epoch 14 Batch 2800 Loss 0.4666
# Epoch 14 Batch 2900 Loss 0.4866
# Epoch 14 Batch 3000 Loss 0.5002
# Epoch 14 Batch 3100 Loss 0.5011
# Epoch 14 Batch 3200 Loss 0.5443
# Epoch 14 Batch 3300 Loss 0.5115
# Epoch 14 Batch 3400 Loss 0.5001
# Epoch 14 Batch 3500 Loss 0.4918
# Epoch 14 Batch 3600 Loss 0.4803
# Epoch 14 Batch 3700 Loss 0.4364
# Epoch 14 Batch 3800 Loss 0.4353
# Epoch 14 Batch 3900 Loss 0.4743
# Epoch 14 Batch 4000 Loss 0.5032
# Epoch 14 Batch 4100 Loss 0.4696
# Epoch 14 Batch 4200 Loss 0.4791
# Epoch 14 Batch 4300 Loss 0.5193
# Epoch 14 Batch 4400 Loss 0.4843
# Epoch 14 Batch 4500 Loss 0.5276
# Epoch 14 Batch 4600 Loss 0.5147
# Epoch 14 Batch 4700 Loss 0.5068
# Epoch 14 Batch 4800 Loss 0.5174
# Epoch 14 Batch 4900 Loss 0.5082
# Epoch 14 Batch 5000 Loss 0.4412
# Epoch 14 Batch 5100 Loss 0.5079
# Epoch 14 Loss 0.488808
# Time taken for 1 epoch 1055.23 sec
#
# Epoch 15 Batch 0 Loss 0.4671
# Epoch 15 Batch 100 Loss 0.5091
# Epoch 15 Batch 200 Loss 0.4992
# Epoch 15 Batch 300 Loss 0.5160
# Epoch 15 Batch 400 Loss 0.4811
# Epoch 15 Batch 500 Loss 0.4875
# Epoch 15 Batch 600 Loss 0.4760
# Epoch 15 Batch 700 Loss 0.5089
# Epoch 15 Batch 800 Loss 0.4787
# Epoch 15 Batch 900 Loss 0.4383
# Epoch 15 Batch 1000 Loss 0.5060
# Epoch 15 Batch 1100 Loss 0.5120
# Epoch 15 Batch 1200 Loss 0.4667
# Epoch 15 Batch 1300 Loss 0.4877
# Epoch 15 Batch 1400 Loss 0.5281
# Epoch 15 Batch 1500 Loss 0.4847
# Epoch 15 Batch 1600 Loss 0.4842
# Epoch 15 Batch 1700 Loss 0.5110
# Epoch 15 Batch 1800 Loss 0.4339
# Epoch 15 Batch 1900 Loss 0.4710
# Epoch 15 Batch 2000 Loss 0.5201
# Epoch 15 Batch 2100 Loss 0.5201
# Epoch 15 Batch 2200 Loss 0.4799
# Epoch 15 Batch 2300 Loss 0.4372
# Epoch 15 Batch 2400 Loss 0.4788
# Epoch 15 Batch 2500 Loss 0.4620
# Epoch 15 Batch 2600 Loss 0.4701
# Epoch 15 Batch 2700 Loss 0.4888
# Epoch 15 Batch 2800 Loss 0.4870
# Epoch 15 Batch 2900 Loss 0.4874
# Epoch 15 Batch 3000 Loss 0.4376
# Epoch 15 Batch 3100 Loss 0.4949
# Epoch 15 Batch 3200 Loss 0.4918
# Epoch 15 Batch 3300 Loss 0.5086
# Epoch 15 Batch 3400 Loss 0.5120
# Epoch 15 Batch 3500 Loss 0.4642
# Epoch 15 Batch 3600 Loss 0.4602
# Epoch 15 Batch 3700 Loss 0.4796
# Epoch 15 Batch 3800 Loss 0.4689
# Epoch 15 Batch 3900 Loss 0.4713
# Epoch 15 Batch 4000 Loss 0.4771
# Epoch 15 Batch 4100 Loss 0.4538
# Epoch 15 Batch 4200 Loss 0.4621
# Epoch 15 Batch 4300 Loss 0.4851
# Epoch 15 Batch 4400 Loss 0.4813
# Epoch 15 Batch 4500 Loss 0.4840
# Epoch 15 Batch 4600 Loss 0.5088
# Epoch 15 Batch 4700 Loss 0.4728
# Epoch 15 Batch 4800 Loss 0.4955
# Epoch 15 Batch 4900 Loss 0.4640
# Epoch 15 Batch 5000 Loss 0.4596
# Epoch 15 Batch 5100 Loss 0.4767
# Epoch 15 Loss 0.484015
# Time taken for 1 epoch 1069.30 sec
#
# Epoch 16 Batch 0 Loss 0.4721
# Epoch 16 Batch 100 Loss 0.5066
# Epoch 16 Batch 200 Loss 0.4535
# Epoch 16 Batch 300 Loss 0.4703
# Epoch 16 Batch 400 Loss 0.4776
# Epoch 16 Batch 500 Loss 0.4366
# Epoch 16 Batch 600 Loss 0.4497
# Epoch 16 Batch 700 Loss 0.4725
# Epoch 16 Batch 800 Loss 0.4867
# Epoch 16 Batch 900 Loss 0.4851
# Epoch 16 Batch 1000 Loss 0.5676
# Epoch 16 Batch 1100 Loss 0.4638
# Epoch 16 Batch 1200 Loss 0.4772
# Epoch 16 Batch 1300 Loss 0.4801
# Epoch 16 Batch 1400 Loss 0.5079
# Epoch 16 Batch 1500 Loss 0.4974
# Epoch 16 Batch 1600 Loss 0.4869
# Epoch 16 Batch 1700 Loss 0.4525
# Epoch 16 Batch 1800 Loss 0.4977
# Epoch 16 Batch 1900 Loss 0.4780
# Epoch 16 Batch 2000 Loss 0.5000
# Epoch 16 Batch 2100 Loss 0.4956
# Epoch 16 Batch 2200 Loss 0.4691
# Epoch 16 Batch 2300 Loss 0.4483
# Epoch 16 Batch 2400 Loss 0.4762
# Epoch 16 Batch 2500 Loss 0.4486
# Epoch 16 Batch 2600 Loss 0.4907
# Epoch 16 Batch 2700 Loss 0.4656
# Epoch 16 Batch 2800 Loss 0.4604
# Epoch 16 Batch 2900 Loss 0.4632
# Epoch 16 Batch 3000 Loss 0.5050
# Epoch 16 Batch 3100 Loss 0.4486
# Epoch 16 Batch 3200 Loss 0.5255
# Epoch 16 Batch 3300 Loss 0.4785
# Epoch 16 Batch 3400 Loss 0.4231
# Epoch 16 Batch 3500 Loss 0.4797
# Epoch 16 Batch 3600 Loss 0.5033
# Epoch 16 Batch 3700 Loss 0.4319
# Epoch 16 Batch 3800 Loss 0.4606
# Epoch 16 Batch 3900 Loss 0.4465
# Epoch 16 Batch 4000 Loss 0.4887
# Epoch 16 Batch 4100 Loss 0.5166
# Epoch 16 Batch 4200 Loss 0.4914
# Epoch 16 Batch 4300 Loss 0.5018
# Epoch 16 Batch 4400 Loss 0.4908
# Epoch 16 Batch 4500 Loss 0.4964
# Epoch 16 Batch 4600 Loss 0.4542
# Epoch 16 Batch 4700 Loss 0.5129
# Epoch 16 Batch 4800 Loss 0.4579
# Epoch 16 Batch 4900 Loss 0.4650
# Epoch 16 Batch 5000 Loss 0.4926
# Epoch 16 Batch 5100 Loss 0.4995
# Epoch 16 Loss 0.479456
# Time taken for 1 epoch 1103.08 sec
#
# Epoch 17 Batch 0 Loss 0.4823
# Epoch 17 Batch 100 Loss 0.5152
# Epoch 17 Batch 200 Loss 0.4559
# Epoch 17 Batch 300 Loss 0.4475
# Epoch 17 Batch 400 Loss 0.4624
# Epoch 17 Batch 500 Loss 0.4618
# Epoch 17 Batch 600 Loss 0.4762
# Epoch 17 Batch 700 Loss 0.4769
# Epoch 17 Batch 800 Loss 0.4695
# Epoch 17 Batch 900 Loss 0.4537
# Epoch 17 Batch 1000 Loss 0.4825
# Epoch 17 Batch 1100 Loss 0.5388
# Epoch 17 Batch 1200 Loss 0.5129
# Epoch 17 Batch 1300 Loss 0.4812
# Epoch 17 Batch 1400 Loss 0.5013
# Epoch 17 Batch 1500 Loss 0.4843
# Epoch 17 Batch 1600 Loss 0.4519
# Epoch 17 Batch 1700 Loss 0.4245
# Epoch 17 Batch 1800 Loss 0.5399
# Epoch 17 Batch 1900 Loss 0.4635
# Epoch 17 Batch 2000 Loss 0.5235
# Epoch 17 Batch 2100 Loss 0.4840
# Epoch 17 Batch 2200 Loss 0.4499
# Epoch 17 Batch 2300 Loss 0.4266
# Epoch 17 Batch 2400 Loss 0.4666
# Epoch 17 Batch 2500 Loss 0.4716
# Epoch 17 Batch 2600 Loss 0.5021
# Epoch 17 Batch 2700 Loss 0.4736
# Epoch 17 Batch 2800 Loss 0.5133
# Epoch 17 Batch 2900 Loss 0.4866
# Epoch 17 Batch 3000 Loss 0.5029
# Epoch 17 Batch 3100 Loss 0.4903
# Epoch 17 Batch 3200 Loss 0.4900
# Epoch 17 Batch 3300 Loss 0.4456
# Epoch 17 Batch 3400 Loss 0.4620
# Epoch 17 Batch 3500 Loss 0.5003
# Epoch 17 Batch 3600 Loss 0.4717
# Epoch 17 Batch 3700 Loss 0.4820
# Epoch 17 Batch 3800 Loss 0.4839
# Epoch 17 Batch 3900 Loss 0.4555
# Epoch 17 Batch 4000 Loss 0.4782
# Epoch 17 Batch 4100 Loss 0.4672
# Epoch 17 Batch 4200 Loss 0.4925
# Epoch 17 Batch 4300 Loss 0.4538
# Epoch 17 Batch 4400 Loss 0.4650
# Epoch 17 Batch 4500 Loss 0.4640
# Epoch 17 Batch 4600 Loss 0.4959
# Epoch 17 Batch 4700 Loss 0.4502
# Epoch 17 Batch 4800 Loss 0.4898
# Epoch 17 Batch 4900 Loss 0.4617
# Epoch 17 Batch 5000 Loss 0.4273
# Epoch 17 Batch 5100 Loss 0.4515
# Epoch 17 Loss 0.475650
# Time taken for 1 epoch 1158.60 sec
#
# Epoch 18 Batch 0 Loss 0.4594
# Epoch 18 Batch 100 Loss 0.4781
# Epoch 18 Batch 200 Loss 0.4645
# Epoch 18 Batch 300 Loss 0.4556
# Epoch 18 Batch 400 Loss 0.4527
# Epoch 18 Batch 500 Loss 0.4946
# Epoch 18 Batch 600 Loss 0.4824
# Epoch 18 Batch 700 Loss 0.4395
# Epoch 18 Batch 800 Loss 0.4326
# Epoch 18 Batch 900 Loss 0.4582
# Epoch 18 Batch 1000 Loss 0.5003
# Epoch 18 Batch 1100 Loss 0.4852
# Epoch 18 Batch 1200 Loss 0.5005
# Epoch 18 Batch 1300 Loss 0.5181
# Epoch 18 Batch 1400 Loss 0.5099
# Epoch 18 Batch 1500 Loss 0.4761
# Epoch 18 Batch 1600 Loss 0.4550
# Epoch 18 Batch 1700 Loss 0.4677
# Epoch 18 Batch 1800 Loss 0.5144
# Epoch 18 Batch 1900 Loss 0.4683
# Epoch 18 Batch 2000 Loss 0.4480
# Epoch 18 Batch 2100 Loss 0.4575
# Epoch 18 Batch 2200 Loss 0.4685
# Epoch 18 Batch 2300 Loss 0.4743
# Epoch 18 Batch 2400 Loss 0.4687
# Epoch 18 Batch 2500 Loss 0.4379
# Epoch 18 Batch 2600 Loss 0.5082
# Epoch 18 Batch 2700 Loss 0.5039
# Epoch 18 Batch 2800 Loss 0.4627
# Epoch 18 Batch 2900 Loss 0.5175
# Epoch 18 Batch 3000 Loss 0.4208
# Epoch 18 Batch 3100 Loss 0.4699
# Epoch 18 Batch 3200 Loss 0.5031
# Epoch 18 Batch 3300 Loss 0.4144
# Epoch 18 Batch 3400 Loss 0.4542
# Epoch 18 Batch 3500 Loss 0.4875
# Epoch 18 Batch 3600 Loss 0.5353
# Epoch 18 Batch 3700 Loss 0.5501
# Epoch 18 Batch 3800 Loss 0.4507
# Epoch 18 Batch 3900 Loss 0.4885
# Epoch 18 Batch 4000 Loss 0.4811
# Epoch 18 Batch 4100 Loss 0.4694
# Epoch 18 Batch 4200 Loss 0.4380
# Epoch 18 Batch 4300 Loss 0.4551
# Epoch 18 Batch 4400 Loss 0.4782
# Epoch 18 Batch 4500 Loss 0.4886
# Epoch 18 Batch 4600 Loss 0.4547
# Epoch 18 Batch 4700 Loss 0.4744
# Epoch 18 Batch 4800 Loss 0.4243
# Epoch 18 Batch 4900 Loss 0.4979
# Epoch 18 Batch 5000 Loss 0.4500
# Epoch 18 Batch 5100 Loss 0.4872
# Epoch 18 Loss 0.471844
# Time taken for 1 epoch 1227.10 sec
#
# Epoch 19 Batch 0 Loss 0.5415
# Epoch 19 Batch 100 Loss 0.5005
# Epoch 19 Batch 200 Loss 0.4818
# Epoch 19 Batch 300 Loss 0.4618
# Epoch 19 Batch 400 Loss 0.4506
# Epoch 19 Batch 500 Loss 0.4609
# Epoch 19 Batch 600 Loss 0.4984
# Epoch 19 Batch 700 Loss 0.4666
# Epoch 19 Batch 800 Loss 0.4825
# Epoch 19 Batch 900 Loss 0.4694
# Epoch 19 Batch 1000 Loss 0.5453
# Epoch 19 Batch 1100 Loss 0.4611
# Epoch 19 Batch 1200 Loss 0.4359
# Epoch 19 Batch 1300 Loss 0.4851
# Epoch 19 Batch 1400 Loss 0.4852
# Epoch 19 Batch 1500 Loss 0.4376
# Epoch 19 Batch 1600 Loss 0.4622
# Epoch 19 Batch 1700 Loss 0.4775
# Epoch 19 Batch 1800 Loss 0.4675
# Epoch 19 Batch 1900 Loss 0.4419
# Epoch 19 Batch 2000 Loss 0.4966
# Epoch 19 Batch 2100 Loss 0.5072
# Epoch 19 Batch 2200 Loss 0.4590
# Epoch 19 Batch 2300 Loss 0.4565
# Epoch 19 Batch 2400 Loss 0.4837
# Epoch 19 Batch 2500 Loss 0.4157
# Epoch 19 Batch 2600 Loss 0.4873
# Epoch 19 Batch 2700 Loss 0.4798
# Epoch 19 Batch 2800 Loss 0.4959
# Epoch 19 Batch 2900 Loss 0.4635
# Epoch 19 Batch 3000 Loss 0.4201
# Epoch 19 Batch 3100 Loss 0.4868
# Epoch 19 Batch 3200 Loss 0.4542
# Epoch 19 Batch 3300 Loss 0.5000
# Epoch 19 Batch 3400 Loss 0.4661
# Epoch 19 Batch 3500 Loss 0.4855
# Epoch 19 Batch 3600 Loss 0.4899
# Epoch 19 Batch 3700 Loss 0.4455
# Epoch 19 Batch 3800 Loss 0.4836
# Epoch 19 Batch 3900 Loss 0.4764
# Epoch 19 Batch 4000 Loss 0.4765
# Epoch 19 Batch 4100 Loss 0.4289
# Epoch 19 Batch 4200 Loss 0.4797
# Epoch 19 Batch 4300 Loss 0.5242
# Epoch 19 Batch 4400 Loss 0.4841
# Epoch 19 Batch 4500 Loss 0.4959
# Epoch 19 Batch 4600 Loss 0.4330
# Epoch 19 Batch 4700 Loss 0.4602
# Epoch 19 Batch 4800 Loss 0.5079
# Epoch 19 Batch 4900 Loss 0.4440
# Epoch 19 Batch 5000 Loss 0.4525
# Epoch 19 Batch 5100 Loss 0.4581
# Epoch 19 Loss 0.468579
# Time taken for 1 epoch 1293.80 sec
#
# Epoch 20 Batch 0 Loss 0.5002
# Epoch 20 Batch 100 Loss 0.4405
# Epoch 20 Batch 200 Loss 0.5298
# Epoch 20 Batch 300 Loss 0.4187
# Epoch 20 Batch 400 Loss 0.4557
# Epoch 20 Batch 500 Loss 0.4432
# Epoch 20 Batch 600 Loss 0.4036
# Epoch 20 Batch 700 Loss 0.4264
# Epoch 20 Batch 800 Loss 0.4449
# Epoch 20 Batch 900 Loss 0.4667
# Epoch 20 Batch 1000 Loss 0.4527
# Epoch 20 Batch 1100 Loss 0.4845
# Epoch 20 Batch 1200 Loss 0.4588
# Epoch 20 Batch 1300 Loss 0.4692
# Epoch 20 Batch 1400 Loss 0.4669
# Epoch 20 Batch 1500 Loss 0.4328
# Epoch 20 Batch 1600 Loss 0.4554
# Epoch 20 Batch 1700 Loss 0.4391
# Epoch 20 Batch 1800 Loss 0.4240
# Epoch 20 Batch 1900 Loss 0.4897
# Epoch 20 Batch 2000 Loss 0.4384
# Epoch 20 Batch 2100 Loss 0.4893
# Epoch 20 Batch 2200 Loss 0.4857
# Epoch 20 Batch 2300 Loss 0.4445
# Epoch 20 Batch 2400 Loss 0.4655
# Epoch 20 Batch 2500 Loss 0.4862
# Epoch 20 Batch 2600 Loss 0.4450
# Epoch 20 Batch 2700 Loss 0.4936
# Epoch 20 Batch 2800 Loss 0.4288
# Epoch 20 Batch 2900 Loss 0.4387
# Epoch 20 Batch 3000 Loss 0.4466
# Epoch 20 Batch 3100 Loss 0.4512
# Epoch 20 Batch 3200 Loss 0.4232
# Epoch 20 Batch 3300 Loss 0.4361
# Epoch 20 Batch 3400 Loss 0.4803
# Epoch 20 Batch 3500 Loss 0.4471
# Epoch 20 Batch 3600 Loss 0.4651
# Epoch 20 Batch 3700 Loss 0.4622
# Epoch 20 Batch 3800 Loss 0.4989
# Epoch 20 Batch 3900 Loss 0.4618
# Epoch 20 Batch 4000 Loss 0.4831
# Epoch 20 Batch 4100 Loss 0.4999
# Epoch 20 Batch 4200 Loss 0.4466
# Epoch 20 Batch 4300 Loss 0.5178
# Epoch 20 Batch 4400 Loss 0.4709
# Epoch 20 Batch 4500 Loss 0.4579
# Epoch 20 Batch 4600 Loss 0.5177
# Epoch 20 Batch 4700 Loss 0.5238
# Epoch 20 Batch 4800 Loss 0.5060
# Epoch 20 Batch 4900 Loss 0.4715
# Epoch 20 Batch 5000 Loss 0.4718
# Epoch 20 Batch 5100 Loss 0.4628
# Epoch 20 Loss 0.464824
# Time taken for 1 epoch 1361.31 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %%
encoder.save('./EncoderModel/')

decoder.save('./DecoderModel/')
# Out:
# INFO:tensorflow:Assets written to: ./EncoderModel/assets
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./DecoderModel/assets
# INFO:tensorflow:Assets written to: ./DecoderModel/assets

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a bird sitting on a plate with a few fries on it. <end>
# Prediction Caption: a mother and white [UNK] and a piece on a white plate next to a red tablecloth. <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Downloading data from https://tensorflow.org/images/surf.jpg
# 64400/64400 [==============================] - 0s 3us/step
# Prediction Caption: a surfer riding a wave and clouds while surfing. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426>
